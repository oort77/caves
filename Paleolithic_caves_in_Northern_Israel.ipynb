# %%
# First install folium if not already installed
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.11/dist-packages (0.19.4)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.11/dist-packages (from folium) (3.1.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from folium) (2.32.3)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.11/dist-packages (from folium) (2025.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->folium) (2024.12.14)

# %%
import folium
from folium import plugins

# caves = [
#     # {"name": "Qesem Cave", "lat": 32.105, "lon": 34.982, "period": "Lower Paleolithic (420,000-200,000 BP)"},
#     {"name": "Tabun Cave", "lat": 32.669, "lon": 35.003, "period": "Lower and Middle Paleolithic (500,000 - 40,000 BP)"},
#     {"name": "Skhul Cave", "lat": 32.670, "lon": 35.004, "period": "Middle Paleolithic (120,000 - 80,000 BP)"},
#     {"name": "Kebara Cave", "lat": 32.760, "lon": 35.000, "period": "Middle Paleolithic (60,000 - 40,000 BP), Upper Paleolithic (40,000 - 10,000 BP)"},
#     {"name": "Amud Cave", "lat": 32.935, "lon": 35.336, "period": "Middle Paleolithic (55,000 - 50,000 BP)"},
#     {"name": "Hayonim Cave", "lat": 32.930, "lon": 35.250, "period": "Middle Paleolithic (250,000 - 100,000 BP), Upper Paleolithic, Epi-Paleolithic"},
#     {"name": "El-Wad Cave", "lat": 32.671, "lon": 35.005, "period": "Epipalaeolithic (45,000 BP onwards), Natufian culture (12,500-10,500 BP)"},
#     {"name": "Misliya Cave", "lat": 33.033, "lon": 35.100, "period": "Lower and Middle Paleolithic (250,000 - 160,000 BP)"},
#     {"name": "Manot Cave", "lat": 33.040, "lon": 35.200, "period": "Early Upper Paleolithic (46,000 - 33,000 BP)"},
#     {"name": "Nahal Me'arot", "lat": 32.670, "lon": 35.010, "period": "Lower Paleolithic (500,000 BP), Middle Paleolithic (250,000-45,000 BP), Natufian culture (15,000 - 11,500 BP)"}
# ]
caves = [
    {"name": "Nahal Me'arot", "lat": 32.670, "lon": 35.010, "period": "Lower Paleolithic (500,000 BP), Middle Paleolithic (250,000-45,000 BP), Natufian culture (15,000 - 11,500 BP)"},
    {"name": "Tabun Cave", "lat": 32.667, "lon": 35.017, "period": "Lower Paleolithic (500,000 BP), Middle Paleolithic (250,000-45,000 BP)"},
    {"name": "Skhul Cave", "lat": 32.669, "lon": 35.013, "period": "Middle Paleolithic (250,000-45,000 BP)"},
    {"name": "El-Wad Cave", "lat": 32.672, "lon": 35.015, "period": "Middle Paleolithic (250,000-45,000 BP), Natufian culture (15,000 - 11,500 BP)"},
    {"name": "Misliya Cave", "lat": 32.666, "lon": 35.017, "period": "Lower Paleolithic (250,000-160,000 BP)"},
    {"name": "Qafzeh Cave", "lat": 32.694, "lon": 35.362, "period": "Middle Paleolithic (100,000-90,000 BP)"},
    {"name": "Kebara Cave", "lat": 32.596, "lon": 34.959, "period": "Middle Paleolithic (250,000-45,000 BP), Natufian culture (15,000 - 11,500 BP)"},
    {"name": "Manot Cave", "lat": 32.987, "lon": 35.268, "period": "Upper Paleolithic (40,000 BP)"},
    {"name": "Amud Cave", "lat": 32.952, "lon": 35.511, "period": "Middle Paleolithic (250,000-45,000 BP)"},
    {"name": "Zuttiyeh Cave", "lat": 33.016, "lon": 35.573, "period": "Middle Paleolithic (150,000 BP)"},
    {"name": "Hayonim Cave", "lat": 33.023, "lon": 35.389, "period": "Middle Paleolithic (250,000-45,000 BP), Natufian culture (15,000 - 11,500 BP)"},
    {"name": "Hilazon Tachtit Cave", "lat": 32.919, "lon": 35.281, "period": "Natufian culture (15,000 - 11,500 BP)"},
    {"name": "Raqefet Cave", "lat": 32.700, "lon": 35.050, "period": "Natufian culture (15,000 - 11,500 BP)"},
    {"name": "Sefunim Cave", "lat": 32.728, "lon": 34.966, "period": "Upper Paleolithic (40,000 BP)"},
    {"name": "Meged Cave", "lat": 32.625, "lon": 35.066, "period": "Upper Paleolithic (30,000 BP)"},
    {"name": "Jamila Cave", "lat": 32.724, "lon": 35.062, "period": "Upper Paleolithic (25,000 BP)"},
    {"name": "Hefzibah Cave", "lat": 32.610, "lon": 35.094, "period": "Middle Paleolithic (250,000-45,000 BP)"},
    {"name": "Carmel Cave", "lat": 32.718, "lon": 34.967, "period": "Upper Paleolithic (30,000 BP)"},
    {"name": "Malham Cave", "lat": 32.715, "lon": 35.007, "period": "Middle Paleolithic (250,000-45,000 BP)"},
    {"name": "Es Skhul Cave", "lat": 32.670, "lon": 35.012, "period": "Middle Paleolithic (250,000-45,000 BP)"},
    {"name": "Geula Cave", "lat": 32.794, "lon": 34.989, "period": "Middle Paleolithic (250,000-45,000 BP)"}
]

# Create a map centered on Northern Israel
map_center_lat = sum(cave['lat'] for cave in caves) / len(caves)
map_center_lon = sum(cave['lon'] for cave in caves) / len(caves)
m = folium.Map(location=[map_center_lat, map_center_lon], zoom_start=10)


# Add markers for each cave
for cave in caves:
    popup_text = f"{cave['name']}<br>Period: {cave['period']}"
    folium.Marker(
        location=[cave['lat'], cave['lon']],
        popup=folium.Popup(popup_text, max_width=300),
        tooltip=cave['name']
    ).add_to(m)

# Fit map to bounds with margin
coords = [(cave['lat'], cave['lon']) for cave in caves]
m.fit_bounds(coords, padding=(0.20,0.20))


# Display the map in Colab
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f31733e90a30431e2272f0a81a6262a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f31733e90a30431e2272f0a81a6262a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f31733e90a30431e2272f0a81a6262a6 = L.map(
#                 &quot;map_f31733e90a30431e2272f0a81a6262a6&quot;,
#                 {
#                     center: [32.75309523809524, 35.12514285714286],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_228cf822024cc8c0b68678951fca3efd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_228cf822024cc8c0b68678951fca3efd.addTo(map_f31733e90a30431e2272f0a81a6262a6);
#
#
#             var marker_869f8f271f3ed9ae2104dad52b1b5657 = L.marker(
#                 [32.67, 35.01],
#                 {
# }
#             ).addTo(map_f31733e90a30431e2272f0a81a6262a6);
#
#
#         var popup_c8e045030a658a617f7fcc19d51253df = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_37e53d2b3ed22654d7055ee9f0ac9137 = $(`&lt;div id=&quot;html_37e53d2b3ed22654d7055ee9f0ac9137&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nahal Me&#x27;arot&lt;br&gt;Period: Lower Paleolithic (500,000 BP), Middle Paleolithic (250,000-45,000 BP), Natufian culture (15,000 - 11,500 BP)&lt;/div&gt;`)[0];
#                 popup_c8e045030a658a617f7fcc19d51253df.setContent(html_37e53d2b3ed22654d7055ee9f0ac9137);
#
#
#
#         marker_869f8f271f3ed9ae2104dad52b1b5657.bindPopup(popup_c8e045030a658a617f7fcc19d51253df)
#         ;
#
#
#
#
#             marker_869f8f271f3ed9ae2104dad52b1b5657.bindTooltip(
#                 `&lt;div&gt;
#                      Nahal Me&#x27;arot
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_41a34e83d69c2500ba98ded19afa186c = L.marker(
#                 [32.667, 35.017],
#                 {
# }
#             ).addTo(map_f31733e90a30431e2272f0a81a6262a6);
#
#
#         var popup_bc0bafa796a08d6019a3087ac5a20dd8 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_80d8ca5dd421e784b59c5766ef75d54d = $(`&lt;div id=&quot;html_80d8ca5dd421e784b59c5766ef75d54d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Tabun Cave&lt;br&gt;Period: Lower Paleolithic (500,000 BP), Middle Paleolithic (250,000-45,000 BP)&lt;/div&gt;`)[0];
#                 popup_bc0bafa796a08d6019a3087ac5a20dd8.setContent(html_80d8ca5dd421e784b59c5766ef75d54d);
#
#
#
#         marker_41a34e83d69c2500ba98ded19afa186c.bindPopup(popup_bc0bafa796a08d6019a3087ac5a20dd8)
#         ;
#
#
#
#
#             marker_41a34e83d69c2500ba98ded19afa186c.bindTooltip(
#                 `&lt;div&gt;
#                      Tabun Cave
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_2dfb23f896259484041dafb3b94d289d = L.marker(
#                 [32.669, 35.013],
#                 {
# }
#             ).addTo(map_f31733e90a30431e2272f0a81a6262a6);
#
#
#         var popup_53c91cf9d97bb97c9b456e3d123a1a14 = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_93ebc512676e5b54d00ce7019a15d786 = $(`&lt;div id=&quot;html_93ebc512676e5b54d00ce7019a15d786&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Skhul Cave&lt;br&gt;Period: Middle Paleolithic (250,000-45,000 BP)&lt;/div&gt;`)[0];
#                 popup_53c91cf9d97bb97c9b456e3d123a1a14.setContent(html_93ebc512676e5b54d00ce7019a15d786);
#
#
#
#         marker_2dfb23f896259484041dafb3b94d289d.bindPopup(popup_53c91cf9d97bb97c9b456e3d123a1a14)
#         ;
#
#
#
#
#             marker_2dfb23f896259484041dafb3b94d289d.bindTooltip(
#                 `&lt;div&gt;
#                      Skhul Cave
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_3ce8cad81cd068b55c9d67ee3aea49c5 = L.marker(
#                 [32.672, 35.015],
#                 {
# }
#             ).addTo(map_f31733e90a30431e2272f0a81a6262a6);
#
#
#         var popup_19346f01538e5f5600f97961f6ea01ca = L.popup({
#   &quot;maxWidth&quot;: 300,
# });
#
#
#
#                 var html_47fc6f4ad29385cbe796fd47085c6f5e = $(`&lt;div id=&quot;html_47fc6f4ad29385cbe796fd47085c6f5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;El-Wad Cave&lt;br&gt;Period: Middle Paleolithic (250,000-45,000 BP), Natufian culture (15,000 - 11,500 BP)&lt;/div&gt;`)[0];
#                 popup_19346f01538e5f5600f97961f6ea01ca.setContent(html_47fc6f4ad29385cbe796fd47085c6f5e);
#
#
#
#         marker_3ce8cad81cd068b55c9d
